# %% [markdown]
# # Liquour Licenses - Regression

# %%
# Import libraries

import numpy as np
import pandas as pd
from math import pi

import matplotlib.pyplot as plt
import seaborn as sns

import statsmodels.api as sm

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression as lr
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import LabelEncoder

# %%
# Read the clean dataset

df = pd.read_csv('ll_cleaned.csv')

# %%
df
# Out:
#       LicenseClass SubClass  LicenseNumber LicenseDate LicenseEndDate  \
# 0             LBD7      BWL          333.0  11/25/2003     04/30/2004
# 1               LB      BWL           84.0  05/01/2003     04/30/2004
# 2               LA      BWL          188.0  05/01/2003     04/30/2004
# 3               LC      BWL           31.0  05/01/2003     04/30/2004
# 4               LB      BWL          145.0  05/01/2003     04/30/2004
# ...            ...      ...            ...         ...            ...
# 18161         LBD7      BWL          277.0  05/01/2017     04/30/2018
# 18162           LA      BWL          215.0  05/01/2017     04/30/2018
# 18163           LB      BWL          246.0  05/01/2017     04/30/2018
# 18164         LBD7      BWL          401.0  05/01/2017     04/30/2018
# 18165         LBD7      BWL          290.0  05/01/2017     04/30/2018
#
#        LicenseYear  LicenseFee CertificateNumber LicenseStatus  \
# 0             2003       100.0              T070   Transferred
# 1             2003      1100.0              0584       Renewed
# 2             2003       715.0              0374       Renewed
# 3             2003       550.0              0831       Renewed
# 4             2003      1100.0              0649       Renewed
# ...            ...         ...               ...           ...
# 18161         2017      1320.0              0834       Renewed
# 18162         2017       858.0              1204       Renewed
# 18163         2017      1520.0              0738       Renewed
# 18164         2017      1820.0              1143       Renewed
# 18165         2017      1320.0              0915       Renewed
#
#       LicenseeFirstName  ...                             CorpName  \
# 0             RONALD F.  ...                         Z AND J, LLC
# 1             MICHAEL F  ...                    DFVS ST.PAUL, LLC
# 2               JUNG J.  ...                            DHK, INC.
# 3                GENEVA  ...  EASTSIDE REINDEER ASSOCIATION, INC.
# 4               ANNE D.  ...      PATRICK'S OF PRATT STREET, INC.
# ...                 ...  ...                                  ...
# 18161           KURT X.  ...                    KURT'S PLACE, LLC
# 18162            JANICE  ...                   SUN BEVERAGE, INC.
# 18163           ASMA K.  ...                     ABM SYSTEMS, INC
# 18164           ERIC D.  ...                    KALI'S COURT, LLC
# 18165        SHANNON M.  ...                       KIE-BRAN, INC.
#
#         EstablishmentDesc DayPerWeek           Description  \
# 0                  Tavern     7 days  Beer, Wine, & Liquor
# 1              Restaurant     7 days  Beer, Wine, & Liquor
# 2      Package goods only     6 days  Beer, Wine, & Liquor
# 3        Non-Profits only     7 days  Beer, Wine, & Liquor
# 4              Restaurant     7 days  Beer, Wine, & Liquor
# ...                   ...        ...                   ...
# 18161              Tavern     7 days  Beer, Wine, & Liquor
# 18162  Package goods only     6 days  Beer, Wine, & Liquor
# 18163          Restaurant     7 days  Beer, Wine, & Liquor
# 18164              Tavern     7 days  Beer, Wine, & Liquor
# 18165              Tavern     7 days  Beer, Wine, & Liquor
#
#                        AddrStreet AddrZip  \
# 0       1633 CHARLES STREET SOUTH   21230
# 1         3103-05 ST. PAUL STREET   21218
# 2        631 WASHINGTON BOULEVARD   21230
# 3        1228 PRESTON STREET EAST   21202
# 4      131 SCHROEDER STREET SOUTH   21223
# ...                           ...     ...
# 18161    601 CLINTON STREET SOUTH   21224
# 18162         1532 HAVENWOOD ROAD   21218
# 18163        3105 ST. PAUL STREET   21218
# 18164       1602-08 THAMES STREET   21231
# 18165         6000 EASTERN AVENUE   21224
#
#                                               Location 1  \
# 0      1633 CHARLES STREET SOUTH\nBaltimore, MD 21230...
# 1      3103-05 ST. PAUL STREET\nBaltimore, MD 21218\n...
# 2      631 WASHINGTON BOULEVARD\nBaltimore, MD 21230\...
# 3      1228 PRESTON STREET EAST\nBaltimore, MD 21202\...
# 4      131 SCHROEDER STREET SOUTH\nBaltimore, MD 2122...
# ...                                                  ...
# 18161  601 CLINTON STREET SOUTH\nBaltimore, MD 21224\...
# 18162  1532 HAVENWOOD ROAD\nBaltimore, MD 21218\n(39....
# 18163  3105 ST. PAUL STREET\nBaltimore, MD 21218\n(39...
# 18164  1602-08 THAMES STREET\nBaltimore, MD 21231\n(3...
# 18165  6000 EASTERN AVENUE\nBaltimore, MD 21224\n(39....
#
#        2010 Census Wards Precincts 2010 Census Neighborhoods  Zip Codes
# 0                            173.0                     222.0    27953.0
# 1                             35.0                     277.0    27307.0
# 2                              1.0                     194.0    27953.0
# 3                            107.0                     180.0    13645.0
# 4                              7.0                     114.0    27632.0
# ...                            ...                       ...        ...
# 18161                        130.0                      30.0    27935.0
# 18162                        212.0                     111.0    27307.0
# 18163                         35.0                     277.0    27307.0
# 18164                        286.0                      68.0    27954.0
# 18165                        138.0                     126.0    27935.0
#
# [18166 rows x 22 columns]

# %%
# Listing the columns

df.columns
# Out:
# Index(['LicenseClass', 'SubClass', 'LicenseNumber', 'LicenseDate',
#        'LicenseEndDate', 'LicenseYear', 'LicenseFee', 'CertificateNumber',
#        'LicenseStatus', 'LicenseeFirstName', 'LicenseeLastName', 'TradeName',
#        'CorpName', 'EstablishmentDesc', 'DayPerWeek', 'Description',
#        'AddrStreet', 'AddrZip', 'Location 1', '2010 Census Wards Precincts',
#        '2010 Census Neighborhoods', 'Zip Codes'],
#       dtype='object')

# %%
# Creating a new df for dropped columns

df_dropped = df.drop(['LicenseClass', 'SubClass', 'LicenseDate', 'LicenseEndDate', 'CertificateNumber', 'LicenseStatus',
        'LicenseeFirstName', 'LicenseeLastName', 'TradeName', 'CorpName', 'EstablishmentDesc', 'DayPerWeek',
        'Description', 'AddrStreet', 'Location 1'], axis=1)

# %%
df_dropped
# Out:
#        LicenseNumber  LicenseYear  LicenseFee  AddrZip  \
# 0              333.0         2003       100.0    21230
# 1               84.0         2003      1100.0    21218
# 2              188.0         2003       715.0    21230
# 3               31.0         2003       550.0    21202
# 4              145.0         2003      1100.0    21223
# ...              ...          ...         ...      ...
# 18161          277.0         2017      1320.0    21224
# 18162          215.0         2017       858.0    21218
# 18163          246.0         2017      1520.0    21218
# 18164          401.0         2017      1820.0    21231
# 18165          290.0         2017      1320.0    21224
#
#        2010 Census Wards Precincts  2010 Census Neighborhoods  Zip Codes
# 0                            173.0                      222.0    27953.0
# 1                             35.0                      277.0    27307.0
# 2                              1.0                      194.0    27953.0
# 3                            107.0                      180.0    13645.0
# 4                              7.0                      114.0    27632.0
# ...                            ...                        ...        ...
# 18161                        130.0                       30.0    27935.0
# 18162                        212.0                      111.0    27307.0
# 18163                         35.0                      277.0    27307.0
# 18164                        286.0                       68.0    27954.0
# 18165                        138.0                      126.0    27935.0
#
# [18166 rows x 7 columns]

# %%
df_dropped.AddrZip.nunique()
# Out:
# 26

# %%
df_dropped.LicenseYear.nunique()
# Out:
# 15

# %%
#df_dropped = pd.get_dummies(df_dropped, columns = ['LicenseYear'])
#df_dropped

# %%
new_df = pd.DataFrame(data=np.c_[df_dropped.drop(['Zip Codes'], axis=1), df_dropped['Zip Codes']], columns= list(df_dropped.drop(['Zip Codes'], axis=1)) + ['Zip Codes'])

# %%
new_df
# Out:
#        LicenseNumber  LicenseYear  LicenseFee  AddrZip  \
# 0              333.0       2003.0       100.0  21230.0
# 1               84.0       2003.0      1100.0  21218.0
# 2              188.0       2003.0       715.0  21230.0
# 3               31.0       2003.0       550.0  21202.0
# 4              145.0       2003.0      1100.0  21223.0
# ...              ...          ...         ...      ...
# 18161          277.0       2017.0      1320.0  21224.0
# 18162          215.0       2017.0       858.0  21218.0
# 18163          246.0       2017.0      1520.0  21218.0
# 18164          401.0       2017.0      1820.0  21231.0
# 18165          290.0       2017.0      1320.0  21224.0
#
#        2010 Census Wards Precincts  2010 Census Neighborhoods  Zip Codes
# 0                            173.0                      222.0    27953.0
# 1                             35.0                      277.0    27307.0
# 2                              1.0                      194.0    27953.0
# 3                            107.0                      180.0    13645.0
# 4                              7.0                      114.0    27632.0
# ...                            ...                        ...        ...
# 18161                        130.0                       30.0    27935.0
# 18162                        212.0                      111.0    27307.0
# 18163                         35.0                      277.0    27307.0
# 18164                        286.0                       68.0    27954.0
# 18165                        138.0                      126.0    27935.0
#
# [18166 rows x 7 columns]

# %%
# Running the regression using sklearn with a test-train split

import math
train_df = new_df.iloc[0:math.ceil(0.8*new_df.shape[0])]
test_df = new_df.iloc[math.ceil(0.8*new_df.shape[0]):]

# %%
from sklearn import preprocessing
nm = preprocessing.Normalizer()
df_nm = nm.fit_transform(new_df)

# %%
df_nm
# Out:
# array([[9.47072309e-03, 5.69665416e-02, 2.84406099e-03, ...,
#         4.92022551e-03, 6.31381539e-03, 7.95000368e-01],
#        [2.42367696e-03, 5.77931543e-02, 3.17386269e-02, ...,
#         1.00986540e-03, 7.99236332e-03, 7.87896986e-01],
#        [5.34600425e-03, 5.69576942e-02, 2.03318778e-02, ...,
#         2.84361928e-05, 5.51662140e-03, 7.94876897e-01],
#        ...,
#        [7.09433839e-03, 5.81678070e-02, 4.38349364e-02, ...,
#         1.00935709e-03, 7.98834038e-03, 7.87500400e-01],
#        [1.13885101e-02, 5.72833540e-02, 5.16884999e-02, ...,
#         8.12247855e-03, 1.93121868e-03, 7.93901277e-01],
#        [8.24625324e-03, 5.73541131e-02, 3.75346699e-02, ...,
#         3.92407913e-03, 3.58285486e-03, 7.94341670e-01]])

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression()
X = train_df.drop(['Zip Codes'], axis=1)
y = train_df['Zip Codes']
print(len(y))
# Out:
# 14533

# %%
lr.normalize= True

# %%
lr.fit(X,y)
# Out:
# LinearRegression(normalize=True)

# %%
test_df
# Out:
#        LicenseNumber  LicenseYear  LicenseFee  AddrZip  \
# 14533          166.0       2016.0      1320.0  21215.0
# 14534           29.0       2016.0      1520.0  21201.0
# 14535           94.0       2016.0       200.0  21230.0
# 14536            8.0       2016.0       165.0  21211.0
# 14537           56.0       2016.0       858.0  21202.0
# ...              ...          ...         ...      ...
# 18161          277.0       2017.0      1320.0  21224.0
# 18162          215.0       2017.0       858.0  21218.0
# 18163          246.0       2017.0      1520.0  21218.0
# 18164          401.0       2017.0      1820.0  21231.0
# 18165          290.0       2017.0      1320.0  21224.0
#
#        2010 Census Wards Precincts  2010 Census Neighborhoods  Zip Codes
# 14533                         63.0                      140.0    27295.0
# 14534                         96.0                      151.0    13642.0
# 14535                        169.0                      137.0    27953.0
# 14536                         20.0                      125.0    14006.0
# 14537                        193.0                      180.0    13645.0
# ...                            ...                        ...        ...
# 18161                        130.0                       30.0    27935.0
# 18162                        212.0                      111.0    27307.0
# 18163                         35.0                      277.0    27307.0
# 18164                        286.0                       68.0    27954.0
# 18165                        138.0                      126.0    27935.0
#
# [3633 rows x 7 columns]

# %%
from sklearn.linear_model import LinearRegression

x_train, x_test, y_train, y_test = train_test_split(train_df.drop(['Zip Codes'], axis=1), train_df['Zip Codes'], test_size=0.3, random_state=100)
lr = LinearRegression()
reg = lr.fit(x_train,y_train)
reg.score(x_test, y_test)
# Out:
# 0.7527441373618422
