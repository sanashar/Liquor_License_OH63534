# %% [markdown]
# # Liquour Licenses - Data Cleaning

# %%
# Import libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Read the downloaded file

dframe = pd.read_csv("Liquor_Licenses.csv", na_values=' ')
dframe
# Out:
#       LicenseClass SubClass  LicenseNumber LicenseDate LicenseEndDate  \
# 0               LA      BWL          141.0  05/01/2008     04/30/2009
# 1               WD       BW            5.0  05/01/2012     04/30/2013
# 2               AE       AE           28.0  07/01/2009     06/30/2010
# 3               WD       BW           52.0  05/01/2004     04/30/2005
# 4               AE       AE            5.0  07/01/2017     06/30/2018
# ...            ...      ...            ...         ...            ...
# 20789         LBD7      BWL          277.0  05/01/2017     04/30/2018
# 20790           LA      BWL          215.0  05/01/2017     04/30/2018
# 20791           LB      BWL          246.0  05/01/2017     04/30/2018
# 20792         LBD7      BWL          401.0  05/01/2017     04/30/2018
# 20793         LBD7      BWL          290.0  05/01/2017     04/30/2018
#
#        LicenseYear  LicenseFee CertificateNumber LicenseStatus  \
# ...

# %%
# Display the dataframe info()

dframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20794 entries, 0 to 20793
# Data columns (total 22 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   LicenseClass                 20794 non-null  object
#  1   SubClass                     20794 non-null  object
#  2   LicenseNumber                20793 non-null  float64
#  3   LicenseDate                  20794 non-null  object
#  4   LicenseEndDate               20794 non-null  object
#  5   LicenseYear                  20794 non-null  int64
#  6   LicenseFee                   20794 non-null  float64
#  7   CertificateNumber            20793 non-null  object
#  8   LicenseStatus                20429 non-null  object
#  9   LicenseeFirstName            20794 non-null  object
#  10  LicenseeLastName             20794 non-null  object
#  11  TradeName                    20788 non-null  object
#  12  CorpName                     19546 non-null  object
# ...

# %%
# Display the missing values

dframe.isna().sum()
# Out:
# LicenseClass                      0
# SubClass                          0
# LicenseNumber                     1
# LicenseDate                       0
# LicenseEndDate                    0
# LicenseYear                       0
# LicenseFee                        0
# CertificateNumber                 1
# LicenseStatus                   365
# LicenseeFirstName                 0
# LicenseeLastName                  0
# TradeName                         6
# CorpName                       1248
# EstablishmentDesc                 0
# DayPerWeek                      616
# Description                     466
# AddrStreet                        0
# AddrZip                           0
# Location 1                        0
# 2010 Census Wards Precincts     590
# 2010 Census Neighborhoods       590
# Zip Codes                       551
# dtype: int64

# %%
sns.heatmap(dframe.isnull(), cbar=False)

# %%
# Drop all NaN

dframe = dframe.dropna()
dframe = dframe.reset_index(drop = True)

# %%
# Display the number of rows & columns left after dropping the NaN

dframe.shape
# Out:
# (18166, 22)

# %%
# Display first 5 rows

dframe.head()
# Out:
#   LicenseClass SubClass  LicenseNumber LicenseDate LicenseEndDate  \
# 0         LBD7      BWL          333.0  11/25/2003     04/30/2004
# 1           LB      BWL           84.0  05/01/2003     04/30/2004
# 2           LA      BWL          188.0  05/01/2003     04/30/2004
# 3           LC      BWL           31.0  05/01/2003     04/30/2004
# 4           LB      BWL          145.0  05/01/2003     04/30/2004
#
#    LicenseYear  LicenseFee CertificateNumber LicenseStatus LicenseeFirstName  \
# 0         2003       100.0              T070   Transferred         RONALD F.
# 1         2003      1100.0              0584       Renewed         MICHAEL F
# 2         2003       715.0              0374       Renewed           JUNG J.
# 3         2003       550.0              0831       Renewed            GENEVA
# 4         2003      1100.0              0649       Renewed           ANNE D.
#
#    ...                             CorpName   EstablishmentDesc DayPerWeek  \
# ...

# %% [markdown]
# ## Export

# %%
# Saving the clean dataset to use to regression analysis

dframe.to_csv('ll_cleaned.csv',index=False)
dframe
# Out:
#       LicenseClass SubClass  LicenseNumber LicenseDate LicenseEndDate  \
# 0             LBD7      BWL          333.0  11/25/2003     04/30/2004
# 1               LB      BWL           84.0  05/01/2003     04/30/2004
# 2               LA      BWL          188.0  05/01/2003     04/30/2004
# 3               LC      BWL           31.0  05/01/2003     04/30/2004
# 4               LB      BWL          145.0  05/01/2003     04/30/2004
# ...            ...      ...            ...         ...            ...
# 18161         LBD7      BWL          277.0  05/01/2017     04/30/2018
# 18162           LA      BWL          215.0  05/01/2017     04/30/2018
# 18163           LB      BWL          246.0  05/01/2017     04/30/2018
# 18164         LBD7      BWL          401.0  05/01/2017     04/30/2018
# 18165         LBD7      BWL          290.0  05/01/2017     04/30/2018
#
#        LicenseYear  LicenseFee CertificateNumber LicenseStatus  \
# ...

# %%
dframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18166 entries, 0 to 18165
# Data columns (total 22 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   LicenseClass                 18166 non-null  object
#  1   SubClass                     18166 non-null  object
#  2   LicenseNumber                18166 non-null  float64
#  3   LicenseDate                  18166 non-null  object
#  4   LicenseEndDate               18166 non-null  object
#  5   LicenseYear                  18166 non-null  int64
#  6   LicenseFee                   18166 non-null  float64
#  7   CertificateNumber            18166 non-null  object
#  8   LicenseStatus                18166 non-null  object
#  9   LicenseeFirstName            18166 non-null  object
#  10  LicenseeLastName             18166 non-null  object
#  11  TradeName                    18166 non-null  object
#  12  CorpName                     18166 non-null  object
# ...
